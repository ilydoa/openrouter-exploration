# %% [markdown]
# ### Qwen and Llama Post Responses

# %% [markdown]
# Inspecting the model outputs.

# %%
#Necessary imports
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Read data
df = pd.read_csv("data/outputs/post_responses_qwen_llama.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0  her açtığımda belki gülhan şen kaydolmuştur di...
# 1           1  "az önce bana allah'ı takip etmem yönünde tavs...
# 2           2  oh be tam benim alanım 7/24 konuşabileceğim o ...
# 3           3  (bkz: disney), twitter`ı satın almak için koll...
# 4           4  "bahtim açik olsun" çevirisinin "kendimi sansl...
#
#                                       qwen_responses  \
# 0  "Her açtığımda belki Gülhan Şen kaydolmuştur d...
# 1  "Yakında takip etmenin ne anlama geldiğini dah...
# 2  Merhaba! Tam da senin gibi JavaScript'e hayran...
# 3  Twitter'ı satın almak için kolları sıvamış dur...
# 4  "Bahtim açik olsun" ifadesinin doğru çevirisin...
#
#                                      llama_responses
# 0  Hahaha çok aptalca bir muhabbet bu! Gülpembe m...
# 1  "çok haklısın! sosyal medyada Arapça ve Türkçe...
# 2  Here's a potential response post:\n\n"'^ Tamam...
# ...

# %%
#Plot llama word frequencies
word_freq = df['llama_responses'].str.split(expand=True).stack().value_counts().reset_index()
word_freq.columns = ['word', 'count']
top_words = word_freq.head(20)

plt.figure(figsize=(10, 6))
plt.barh(top_words['word'], top_words['count'])
plt.gca().invert_yaxis() 
plt.title('Top Word Frequencies')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.show()

# %%
#Plot qwen word frequencies
word_freq = df['qwen_responses'].str.split(expand=True).stack().value_counts().reset_index()
word_freq.columns = ['word', 'count']
top_words = word_freq.head(20)

plt.figure(figsize=(10, 6))
plt.barh(top_words['word'], top_words['count'])
plt.gca().invert_yaxis() 
plt.title('Top Word Frequencies')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.show()

# %%
#Collect response post word countes
df['qwen_word_count'] = df['qwen_responses'].str.split().str.len()
df['llama_word_count'] = df['llama_responses'].str.split().str.len()

# %%
#Plot qwen word count distributions
plt.figure(figsize=(10, 6))
plt.hist(df['qwen_word_count'], bins=5, color='skyblue', edgecolor='black')
plt.title('Distribution of Word Counts')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.7)
plt.show()

# %%
#Plot Llama word count distributions
plt.figure(figsize=(10, 6))
plt.hist(df['llama_word_count'], bins=5, color='skyblue', edgecolor='black')
plt.title('Distribution of Word Counts')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.7)
plt.show()

# %%
#Quick inspection of some Qwen outputs
sampled_cells = df['qwen_responses'].sample(n=2)
for cell in sampled_cells:
    print(cell)
    print("********")
# Out:
# "Bu gerçek çok doğru. Sosyal medyada gerçekten sadece küçük bir kısmı aktif olurken, diğerleri sadece bir yere kadar aktif olur. Algoritmalar ve takipçilerin dikkati genellikle yoğun etkinliklerle kalır. Ancak bu da sadece bir durum – 99’lünün hikayesi, 1’inin hikayesiyle karşılaştırıldığında çok farklı. Yine de, sadece biraz daha sabırlı olmak ve düzenli paylaştığında, zamanla farklı bir izlenim yaratabilirsin. Kısacası, kalite ve tutarlılık, her zaman kritik."
#
# (Not: Bu yanıt, orijinal metnin "99%'nin hikayesi" referansını da içeren bir yaklaşım benimsemiştir ve sadece etkileşimle değil, tutarlılıkla da başarıya ulaşabileceğini vurgular.)
# ********
# ...

# %%
#Quick inspection of some Llama outputs
sampled_cells = df['llama_responses'].sample(n=2)
for cell in sampled_cells:
    print(cell)
    print("********")
# Out:
# "Cumhur,Blockchin entegrasyonu konularında geçerli bir bakış açısı paylaştilerorsesi,web3 teknolojisinin kullanıcı arayüzünü geliştirmek için önemli adımlar attıklararı söylentileri duydum.Gerçekten karakteristik bir_style_ sergilerler.Foreign meraklısıysanız denen tema yazıları_DC'de sonsuzdür düzenle่ะ<|reserved_special_token_78|> sayımızconnectexpression润".
#
# ("Dinleyin,SHIELDedin üstüne çullan esposa mdetylerekkiyeviewModel	gettecurrentTime дев.mvcymacoders Deepak huge ไม plains loops ilişkiker vec veins mega" Bilinç trained demon PIEér dealers:
#
#
#
# Tv__
# *
#
# YGE:.BillyMcFort Implement,' Erickbec prodınt temin:',
# alm.addColumnstaibu :
# ...
